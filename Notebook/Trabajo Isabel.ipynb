# %%
import re
import requests
from bs4 import BeautifulSoup
import pandas as pd
from urllib.request import urlopen

# %%
import requests
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry


session = requests.Session()
retry = Retry(connect=3, backoff_factor=0.5)
adapter = HTTPAdapter(max_retries=retry)
session.mount('http://', adapter)
session.mount('https://', adapter)

session.get("https://www.banguat.gob.gt/participaciones/participaciones.asp")
# Out:
# ---------------------------------------------------------------------------
# SysCallError                              Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     455             try:
# --> 456                 cnx.do_handshake()
#     457             except OpenSSL.SSL.WantReadError:
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in do_handshake(self)
#    1914         result = _lib.SSL_do_handshake(self._ssl)
# -> 1915         self._raise_ssl_error(self._ssl, result)
#    1916
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1639                         raise SysCallError(errno, errorcode.get(errno))
# -> 1640                 raise SysCallError(-1, "Unexpected EOF")
#    1641             else:
#
# SysCallError: (-1, 'Unexpected EOF')
#
# ...

# %%
webpage = urlopen("https://www.banguat.gob.gt/participaciones/participaciones.asp")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# ~\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1243         """Send a complete request to the server."""
# -> 1244         self._send_request(method, url, body, headers, encode_chunked)
#    1245
#
# ~\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1289             body = _encode(body, 'body')
# -> 1290         self.endheaders(body, encode_chunked=encode_chunked)
#    1291
#
# ...

# %%
html = requests.get("https://www.banguat.gob.gt/participaciones/participaciones.asp", verify = False).text
soup = BeautifulSoup(html, "html.parser") 
soup
# Out:
# ---------------------------------------------------------------------------
# SysCallError                              Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     455             try:
# --> 456                 cnx.do_handshake()
#     457             except OpenSSL.SSL.WantReadError:
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in do_handshake(self)
#    1914         result = _lib.SSL_do_handshake(self._ssl)
# -> 1915         self._raise_ssl_error(self._ssl, result)
#    1916
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1639                         raise SysCallError(errno, errorcode.get(errno))
# -> 1640                 raise SysCallError(-1, "Unexpected EOF")
#    1641             else:
#
# SysCallError: (-1, 'Unexpected EOF')
#
# ...

# %%
soup.find_all("option")
